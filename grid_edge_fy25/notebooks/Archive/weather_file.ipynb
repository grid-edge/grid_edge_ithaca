# %%
pip install diyepw
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 6.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 20.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 31.4 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# CREATE A WEATHER FILE FOR TOMKINS COUNTY

from diyepw import create_amy_epw_files_for_years_and_wmos
import os

# Set your desired output directory
output_dir = "weather_files"

# Make sure it exists
os.makedirs(output_dir, exist_ok=True)

# Generate the AMY EPW file into your desired directory
create_amy_epw_files_for_years_and_wmos(
    years=[2024],
    wmo_indices=[724940],
    max_records_to_interpolate=10,
    max_records_to_impute=25,
    max_missing_amy_rows=24,
    allow_downloads=True,
    amy_epw_dir=output_dir  # << This is what sets the output path
)
# Out:
# 2025-07-22 20:59:15,880 Creating AMY EPW for year 2024 and WMO 724940...
# 2025-07-22 20:59:15,882 No amy_dir was specified - downloaded AMY files will be stored in the default location at /Users/tcharan/.pyenv/versions/3.13.2/lib/python3.13/site-packages/diyepw/data/noaa_isd_lite_files
# 2025-07-22 20:59:15,946 TMY EPW file (/Users/tcharan/.pyenv/versions/3.13.2/lib/python3.13/site-packages/diyepw/data/tmy_epw_files/USA_CA_San.Francisco.Intl.AP.724940_TMY3.epw) already exists, won't download again.
# 2025-07-22 20:59:15,961 2024 is a leap year, using the interpolation strategy to populate TMY data for Feb. 29
# {2024: {724940: ['weather_files/USA_CA_San-Francisco-Intl-AP.724940_AMY_2024.epw']}}
